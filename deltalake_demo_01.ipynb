# %%
# %sql

create table orders(
    order_id int,
    order_date date,
    customer_id int,
    order_status string
)

# %%
# %sql

insert into orders
values(1, '2022-01-01', 1, 'placed'),
(2, '2022-01-02', 2, 'shipped')

# %%
# %sql

select * from orders

# %%
# %sql

describe formatted orders
